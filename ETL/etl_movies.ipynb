# %%
import numpy as np
import pandas as pd

# %%
#abro el csv con pandas
movies= pd.read_csv('../Datos/movies_dataset.csv')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB
# C:\Users\clari\AppData\Local\Temp\ipykernel_7612\3357341811.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies= pd.read_csv('../Datos/movies_dataset.csv')

# %%
#selecciona la columna y la convierto en un diccionario con el fin de prepararla para el siguiente paso
nombres= movies['belongs_to_collection']
dict(nombres)
nombres
# Out:
# 0        {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                      NaN
# 2        {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                      NaN
# 4        {'id': 96871, 'name': 'Father of the Bride Col...
#                                ...
# 45461                                                  NaN
# 45462                                                  NaN
# 45463                                                  NaN
# 45464                                                  NaN
# 45465                                                  NaN
# Name: belongs_to_collection, Length: 45466, dtype: object

# %%
# Busco iterar toda la serie, verificar que hay diccionario para tomar el valor de la clave 'name', contemplando los njulos
import json
import pandas as pd

def obtener_nombres(series):
    for nombre_dict_str in series:
        if pd.isnull(nombre_dict_str):
            yield None
        else:
            nombre_json = str(nombre_dict_str).replace("'", '"')
            try:
                nombre_dict = json.loads(nombre_json)
                if isinstance(nombre_dict, dict):  # Verificar que sea un diccionario
                    nombre = nombre_dict.get('name')
                    if nombre:
                        yield nombre
            except json.JSONDecodeError:
                pass

nombres = obtener_nombres(movies['belongs_to_collection'])

#guardo los datos en la lista collection
collection = []
for nombre in nombres:
   collection.append(nombre)

collection
# Out:
# ['Toy Story Collection',
#  None,
#  'Grumpy Old Men Collection',
#  None,
#  'Father of the Bride Collection',
#  None,
#  None,
#  None,
#  None,
#  'James Bond Collection',
#  None,
#  None,
#  'Balto Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Ace Ventura Collection',
#  None,
#  'Chili Palmer Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Babe Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Mortal Kombat Collection',
#  None,
#  None,
#  None,
#  'Pocahontas Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Lawnmower Man Collection',
#  None,
#  None,
#  'Friday Collection',
#  'From Dusk Till Dawn Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Muppet Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Neverending Story Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Bad Boys Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Batman Collection',
#  None,
#  None,
#  'Brooklyn Cigar Store Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Mexico Trilogy',
#  None,
#  'Die Hard Collection',
#  'Teenage Apocalypse Trilogy',
#  None,
#  None,
#  'Free Willy Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Power Rangers Collection',
#  None,
#  None,
#  None,
#  'Síť (kolekce)',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Showgirls Collection',
#  'Brooklyn Cigar Store Collection',
#  None,
#  'Species Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Under Siege Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Burnt by the Sun Trilogy',
#  None,
#  'Before... Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Clerks Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Dumb and Dumber Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'A Goofy Movie Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Vampire Chronicles',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Star Wars Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Poison Ivy Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Three Colors Collection',
#  'Three Colors Collection',
#  'Three Colors Collection',
#  None,
#  None,
#  None,
#  None,
#  'Swan Princess Series',
#  None,
#  None,
#  None,
#  'The Santa Clause Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Tales from the Crypt Collection',
#  'Star Trek: The Next Generation Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Ace Ventura Collection',
#  None,
#  None,
#  None,
#  None,
#  'The Jack Ryan Collection',
#  None,
#  None,
#  None,
#  'The Crow Collection',
#  None,
#  'The Flintstones (Live-Action) Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Lion King Collection',
#  None,
#  'A Nightmare on Elm Street Collection',
#  'The Mask Collection',
#  None,
#  None,
#  'Naked Gun Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Speed Collection',
#  None,
#  'Timecop Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Street Fighter',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Highlander Collection',
#  None,
#  None,
#  None,
#  None,
#  'Addams Family Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Beverly Hills Cop Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'City Slickers Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Endless Summer Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Free Willy Collection',
#  None,
#  'The Fugitive / U.S. Marshals Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Hard Target Collection',
#  None,
#  'Hot Shots! Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Jurassic Park Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Karate Kid Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'RoboCop Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Secret Garden Collection',
#  None,
#  'The Shadow Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Blade Runner Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Home Alone Collection',
#  None,
#  'Aladdin Collection',
#  'The Terminator Collection',
#  None,
#  None,
#  'Batman Collection',
#  'The Hannibal Lecter Anthology',
#  None,
#  'Beauty and the Beast Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Candyman Collection',
#  None,
#  None,
#  'Heavy Metal Collection',
#  'Hellraiser Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'All Dogs Go to Heaven Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Mission: Impossible Collection',
#  None,
#  None,
#  None,
#  None,
#  'DragonHeart Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Bloodsport Collection',
#  'The Apu Collection',
#  'The Apu Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Lemmy Caution Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Visitors Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Ghost in the Shell Collection',
#  None,
#  None,
#  None,
#  'Wallace & Gromit Collection',
#  None,
#  None,
#  'The Arrival Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Trainspotting Collection',
#  None,
#  'Independence Day Collection',
#  None,
#  None,
#  'The Hunchback of Notre Dame Collection',
#  None,
#  None,
#  None,
#  None,
#  'The Nutty Professor Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Crow Collection',
#  None,
#  None,
#  'Tales from the Crypt Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Escape From ... Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Godfather Collection',
#  None,
#  'Police Story Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Police Story Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Land Before Time Collection',
#  None,
#  None,
#  'Halloween Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Space Odyssey Series',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Thin Man Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Living Dead Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Mighty Ducks Collection',
#  None,
#  'Witch Mountain Collection',
#  'Herbie Collection',
#  'Herbie Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Cinderella Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'The Fox and the Hound Collection',
#  'Freeway Collection',
#  None,
#  'Die Hard Collection',
#  'The Lawnmower Man Collection',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
#PROCESO CON EL FIN DE COMPARAR
#data frame de belongs
df_anidado= pd.DataFrame(movies['belongs_to_collection'], columns=['belongs_to_collection'])
df_anidado

#dataframe solo de nombres de colecciones
df_collection= pd.DataFrame(collection, columns=['collection'])
df_collection
#uno los dataframe por filas para comprobar que coinciden  los datos 
data_unida=pd.concat([df_anidado, df_collection], axis=1)

data_unida.head(5)
# Out:
#                                belongs_to_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                NaN
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                NaN
# 4  {'id': 96871, 'name': 'Father of the Bride Col...
#
#                        collection
# 0            Toy Story Collection
# 1                            None
# 2       Grumpy Old Men Collection
# 3                            None
# 4  Father of the Bride Collection

# %%
# Agregar el DataFrame collection al DataFrame existente
movies = pd.concat([movies, df_collection], axis=1)
movies.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...      revenue  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...  373554033.0
# 1  When siblings Judy and Peter discover an encha...  ...  262797249.0
# 2  A family wedding reignites the ancient feud be...  ...          0.0
# 3  Cheated on, mistreated and stepped on, the wom...  ...   81452156.0
# 4  Just when George Banks has recovered from his ...  ...   76578911.0
#
#   runtime                                   spoken_languages    status  \
# 0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2   101.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3   127.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4   106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count  \
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
#                        collection
# 0            Toy Story Collection
# 1                            None
# 2       Grumpy Old Men Collection
# 3                            None
# 4  Father of the Bride Collection
#
# [5 rows x 25 columns]

# %%
movies['genres']
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 45461    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                        [{'id': 18, 'name': 'Drama'}]
# 45463    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                   []
# 45465                                                   []
# Name: genres, Length: 45466, dtype: object

# %%
#en cada fila de genres aplico la funcion
movie_genres = movies['genres'].apply(lambda x: [d['name'] for d in eval(x)] if pd.notnull(x) else [])
print(movie_genres)
# Out:
# 0         [Animation, Comedy, Family]
# 1        [Adventure, Fantasy, Family]
# 2                   [Romance, Comedy]
# 3            [Comedy, Drama, Romance]
# 4                            [Comedy]
#                      ...
# 45461                 [Drama, Family]
# 45462                         [Drama]
# 45463       [Action, Drama, Thriller]
# 45464                              []
# 45465                              []
# Name: genres, Length: 45466, dtype: object

# %%
#aplico los cambios al df
movies['genres']= movie_genres
movies['genres']
# Out:
# 0         [Animation, Comedy, Family]
# 1        [Adventure, Fantasy, Family]
# 2                   [Romance, Comedy]
# 3            [Comedy, Drama, Romance]
# 4                            [Comedy]
#                      ...
# 45461                 [Drama, Family]
# 45462                         [Drama]
# 45463       [Action, Drama, Thriller]
# 45464                              []
# 45465                              []
# Name: genres, Length: 45466, dtype: object

# %%
movies['production_countries']
# Out:
# 0        [{'iso_3166_1': 'US', 'name': 'United States o...
# 1        [{'iso_3166_1': 'US', 'name': 'United States o...
# 2        [{'iso_3166_1': 'US', 'name': 'United States o...
# 3        [{'iso_3166_1': 'US', 'name': 'United States o...
# 4        [{'iso_3166_1': 'US', 'name': 'United States o...
#                                ...
# 45461               [{'iso_3166_1': 'IR', 'name': 'Iran'}]
# 45462        [{'iso_3166_1': 'PH', 'name': 'Philippines'}]
# 45463    [{'iso_3166_1': 'US', 'name': 'United States o...
# 45464             [{'iso_3166_1': 'RU', 'name': 'Russia'}]
# 45465     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# Name: production_countries, Length: 45466, dtype: object

# %%
#expresion regular para extraer los name referidos a los paises
movies['production_countries']= movies['production_countries'].str.extract(r"'name': '([^']*)'")

# %%
movies['production_countries']
# Out:
# 0        United States of America
# 1        United States of America
# 2        United States of America
# 3        United States of America
# 4        United States of America
#                    ...
# 45461                        Iran
# 45462                 Philippines
# 45463    United States of America
# 45464                      Russia
# 45465              United Kingdom
# Name: production_countries, Length: 45466, dtype: object

# %%
movies
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                              genres                              homepage  \
# 0       [Animation, Comedy, Family]  http://toystory.disney.com/toy-story
# 1      [Adventure, Fantasy, Family]                                   NaN
# 2                 [Romance, Comedy]                                   NaN
# 3          [Comedy, Drama, Romance]                                   NaN
# 4                          [Comedy]                                   NaN
# ...                             ...                                   ...
# 45461               [Drama, Family]  http://www.imdb.com/title/tt6209470/
# 45462                       [Drama]                                   NaN
# 45463     [Action, Drama, Thriller]                                   NaN
# 45464                            []                                   NaN
# 45465                            []                                   NaN
#
#            id    imdb_id original_language               original_title  \
# 0         862  tt0114709                en                    Toy Story
# 1        8844  tt0113497                en                      Jumanji
# 2       15602  tt0113228                en             Grumpier Old Men
# 3       31357  tt0114885                en            Waiting to Exhale
# 4       11862  tt0113041                en  Father of the Bride Part II
# ...       ...        ...               ...                          ...
# 45461  439050  tt6209470                fa                      رگ خواب
# 45462  111109  tt2028550                tl          Siglo ng Pagluluwal
# 45463   67758  tt0303758                en                     Betrayal
# 45464  227506  tt0008536                en          Satana likuyushchiy
# 45465  461257  tt6980792                en                     Queerama
#
#                                                 overview  ... release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4      Just when George Banks has recovered from his ...  ...   1995-02-10
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45461          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464          0.0    87.0                                                 []
# 45465          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [45466 rows x 24 columns]

# %%
movies['production_companies']=movies['production_companies'].str.extract(r"'name': '([^']*)'")
movies['production_companies']
# Out:
# 0                       Pixar Animation Studios
# 1                              TriStar Pictures
# 2                                  Warner Bros.
# 3        Twentieth Century Fox Film Corporation
# 4                         Sandollar Productions
#                           ...
# 45461                                       NaN
# 45462                               Sine Olivia
# 45463                   American World Pictures
# 45464                                 Yermoliev
# 45465                                       NaN
# Name: production_companies, Length: 45466, dtype: object

# %%
movies["spoken_languages"]=movies["spoken_languages"].str.extract(r"'name': '([^']*)'")
movies["spoken_languages"]
# Out:
# 0        English
# 1        English
# 2        English
# 3        English
# 4        English
#           ...
# 45461      فارسی
# 45462
# 45463    English
# 45464        NaN
# 45465    English
# Name: spoken_languages, Length: 45466, dtype: object

# %%
#b)Los valores nulos de los campos revenue, budget deben ser rellenados por el número 0
movies['revenue'].fillna(0,inplace=True)
movies['budget'].fillna(0,inplace=True)

# %%
#c) Eliminar valores nulos en release_date
movies= movies.dropna(subset=['release_date'])
movies['release_date'].isnull().sum()
# Out:
# 0

# %%
#d) De haber fechas, deberá tener el formato AAAA-mm-dd, además deberá crear la columna release_yeardonde extraerán el año de la fecha de estreno.
#hay algunos formatos bien, pero pasamos to_datetime para igual todos los datos
movies['release_date'] = pd.to_datetime(movies['release_date'], errors='coerce')
movies['release_date'] = pd.to_datetime(movies['release_date']).dt.strftime('%Y-%m-%d')#formato solicitado
# Out:
# C:\Users\clari\AppData\Local\Temp\ipykernel_7612\3881058459.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['release_date'] = pd.to_datetime(movies['release_date'], errors='coerce')
# C:\Users\clari\AppData\Local\Temp\ipykernel_7612\3881058459.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['release_date'] = pd.to_datetime(movies['release_date']).dt.strftime('%Y-%m-%d')#formato solicitado

# %%
#extraigo el año de release_date y lo paso como un DF
año = movies['release_date'].str.slice(0, 4)
año= list(año)
df_año= pd.DataFrame(año, columns=['release_year'])
df_año   # 45376 filas
# Out:
#       release_year
# 0             1995
# 1             1995
# 2             1995
# 3             1995
# 4             1995
# ...            ...
# 45374         1991
# 45375         2011
# 45376         2003
# 45377         1917
# 45378         2017
#
# [45379 rows x 1 columns]

# %%
#hago lo mismo con release_date. Para luego sumarlo como una nueva columna modificada
date= movies['release_date']
date= list(date)
df_date= pd.DataFrame(date, columns=['release_date'])
df_date= df_date.dropna()
df_date  #45376 filas
# Out:
#       release_date
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
# ...            ...
# 45374   1991-05-13
# 45375   2011-11-17
# 45376   2003-08-01
# 45377   1917-10-21
# 45378   2017-06-09
#
# [45376 rows x 1 columns]

# %%
#Al comprobar que tiene la misma cantidad de filas y no hay nulos. Elimino el release_date.
movies.drop(columns=['release_date'], inplace=True)
movies.columns
# Out:
# C:\Users\clari\AppData\Local\Temp\ipykernel_7612\2631306420.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.drop(columns=['release_date'], inplace=True)
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'revenue', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
#Ahora concateno al DF original, las nuevas columnas
movies = pd.concat([movies, df_date, df_año], axis=1)

# %%
#e)Cree la columna con el retorno de inversión, llame return con los campos revenuey budget, dividiendo estas dos últimas revenue / budget, cuando no haya datos disponibles para calcularlo, deberá tomar el valor 0.
#me tira error! debo convertir los datos a float
retorno = ((pd.to_numeric(movies['revenue'], errors='coerce')) /  (pd.to_numeric(movies['budget'], errors='coerce')))
retorno = pd.DataFrame(retorno, columns=['return'])
retorno.fillna(0, inplace=True)
retorno = retorno.replace(np.inf,0)
retorno
# Out:
#           return
# 0      12.451801
# 1       4.043035
# 2       0.000000
# 3       5.090760
# 4       0.000000
# ...          ...
# 44978   0.000000
# 45070   0.000000
# 45148   0.000000
# 45203   0.000000
# 45338   0.000000
#
# [45464 rows x 1 columns]

# %%
movies = pd.concat([movies, retorno], axis=1)
movies.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                          genres                              homepage     id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story    862
# 1  [Adventure, Fantasy, Family]                                   NaN   8844
# 2             [Romance, Comedy]                                   NaN  15602
# 3      [Comedy, Drama, Romance]                                   NaN  31357
# 4                      [Comedy]                                   NaN  11862
#
#      imdb_id original_language               original_title  \
# 0  tt0114709                en                    Toy Story
# 1  tt0113497                en                      Jumanji
# 2  tt0113228                en             Grumpier Old Men
# 3  tt0114885                en            Waiting to Exhale
# 4  tt0113041                en  Father of the Bride Part II
#
#                                             overview  ... spoken_languages  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...          English
# 1  When siblings Judy and Peter discover an encha...  ...          English
# 2  A family wedding reignites the ancient feud be...  ...          English
# 3  Cheated on, mistreated and stepped on, the wom...  ...          English
# 4  Just when George Banks has recovered from his ...  ...          English
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video  vote_average vote_count release_date  \
# 0                    Toy Story  False           7.7     5415.0   1995-10-30
# 1                      Jumanji  False           6.9     2413.0   1995-12-15
# 2             Grumpier Old Men  False           6.5       92.0   1995-12-22
# 3            Waiting to Exhale  False           6.1       34.0   1995-12-22
# 4  Father of the Bride Part II  False           5.7      173.0   1995-02-10
#
#   release_year     return
# 0         1995  12.451801
# 1         1995   4.043035
# 2         1995   0.000000
# 3         1995   5.090760
# 4         1995   0.000000
#
# [5 rows x 26 columns]

# %%
# Contar los valores NaN en cada fila
num_nan = movies.isnull().sum(axis=1)

# Filtro y elimino las filas que tienen más de 4 NaN (4, porque conclui que con solo 3 puede igual ser relevante )
movies = movies.dropna(thresh=movies.shape[1]-4)

movies
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45449  False                                                NaN         0
# 45454  False                                                NaN         0
# 45456  False                                                NaN         0
# 45458  False                                                NaN         0
# 45463  False                                                NaN         0
#
#                              genres                              homepage  \
# 0       [Animation, Comedy, Family]  http://toystory.disney.com/toy-story
# 1      [Adventure, Fantasy, Family]                                   NaN
# 2                 [Romance, Comedy]                                   NaN
# 3          [Comedy, Drama, Romance]                                   NaN
# 4                          [Comedy]                                   NaN
# ...                             ...                                   ...
# 45449           [Animation, Family]                                   NaN
# 45454               [Comedy, Drama]                                   NaN
# 45456   [Horror, Mystery, Thriller]                                   NaN
# 45458                      [Horror]                                   NaN
# 45463     [Action, Drama, Thriller]                                   NaN
#
#            id    imdb_id original_language                    original_title  \
# 0         862  tt0114709                en                         Toy Story
# 1        8844  tt0113497                en                           Jumanji
# 2       15602  tt0113228                en                  Grumpier Old Men
# 3       31357  tt0114885                en                 Waiting to Exhale
# 4       11862  tt0113041                en       Father of the Bride Part II
# ...       ...        ...               ...                               ...
# 45449   14885  tt0457437                en  Pooh's Heffalump Halloween Movie
# 45454  420346  tt4130180                en                 The Morning After
# 45456   84419  tt0038621                en                  House of Horrors
# 45458  289923  tt0252966                en               The Burkittsville 7
# 45463   67758  tt0303758                en                          Betrayal
#
#                                                 overview  ...  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...
# 1      When siblings Judy and Peter discover an encha...  ...
# 2      A family wedding reignites the ancient feud be...  ...
# 3      Cheated on, mistreated and stepped on, the wom...  ...
# 4      Just when George Banks has recovered from his ...  ...
# ...                                                  ...  ...
# 45449  It's Halloween in the 100 Acre Wood, and Roo's...  ...
# 45454  The Morning After is a feature film that consi...  ...
# 45456  An unsuccessful sculptor saves a madman named ...  ...
# 45458  A film archivist revisits the story of Rustin ...  ...
# 45463  When one of her hits goes wrong, a professiona...  ...
#
#       spoken_languages    status  \
# 0              English  Released
# 1              English  Released
# 2              English  Released
# 3              English  Released
# 4              English  Released
# ...                ...       ...
# 45449          English  Released
# 45454          English  Released
# 45456          English  Released
# 45458          English  Released
# 45463          English  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45449                 Celebrate Lumpy's First Halloween.
# 45454                          What happened last night?
# 45456                                Meet...The CREEPER!
# 45458  Do you know what happened 50 years before "The...
# 45463                             A deadly game of wits.
#
#                                   title  video  vote_average vote_count  \
# 0                             Toy Story  False           7.7     5415.0
# 1                               Jumanji  False           6.9     2413.0
# 2                      Grumpier Old Men  False           6.5       92.0
# 3                     Waiting to Exhale  False           6.1       34.0
# 4           Father of the Bride Part II  False           5.7      173.0
# ...                                 ...    ...           ...        ...
# 45449  Pooh's Heffalump Halloween Movie  False           5.4        7.0
# 45454                 The Morning After  False           4.0        2.0
# 45456                  House of Horrors  False           6.3        8.0
# 45458               The Burkittsville 7  False           7.0        1.0
# 45463                          Betrayal  False           3.8        6.0
#
#       release_date release_year     return
# 0       1995-10-30         1995  12.451801
# 1       1995-12-15         1995   4.043035
# 2       1995-12-22         1995   0.000000
# 3       1995-12-22         1995   5.090760
# 4       1995-02-10         1995   0.000000
# ...            ...          ...        ...
# 45449          NaN          NaN   0.000000
# 45454          NaN          NaN   0.000000
# 45456          NaN          NaN   0.000000
# 45458          NaN          NaN   0.000000
# 45463          NaN          NaN   0.000000
#
# [40240 rows x 26 columns]

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'revenue', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count',
#        'release_date', 'release_year', 'return'],
#       dtype='object')

# %%
#f) Eliminar las columnas que no se utilizarán, video, imdb_id, adult, original_title, poster_pathy homepage.(elimino belong_to_collection ya que esta desanidado y e creado una nueva columna)
movies.drop(columns=['video','imdb_id','adult','original_title','poster_path', 'homepage','belongs_to_collection',], inplace=True)
movies.columns
# Out:
# Index(['budget', 'genres', 'id', 'original_language', 'overview', 'popularity',
#        'production_companies', 'production_countries', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'release_date', 'release_year', 'return'],
#       dtype='object')

# %%
movies.to_csv('movies_limpio.csv')

# %%
movies
# Out:
#          budget                        genres      id original_language  \
# 0      30000000   [Animation, Comedy, Family]     862                en
# 1      65000000  [Adventure, Fantasy, Family]    8844                en
# 2             0             [Romance, Comedy]   15602                en
# 3      16000000      [Comedy, Drama, Romance]   31357                en
# 4             0                      [Comedy]   11862                en
# ...         ...                           ...     ...               ...
# 45449         0           [Animation, Family]   14885                en
# 45454         0               [Comedy, Drama]  420346                en
# 45456         0   [Horror, Mystery, Thriller]   84419                en
# 45458         0                      [Horror]  289923                en
# 45463         0     [Action, Drama, Thriller]   67758                en
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45449  It's Halloween in the 100 Acre Wood, and Roo's...   2.568495
# 45454  The Morning After is a feature film that consi...   0.139936
# 45456  An unsuccessful sculptor saves a madman named ...   0.222814
# 45458  A film archivist revisits the story of Rustin ...    0.38645
# 45463  When one of her hits goes wrong, a professiona...   0.903007
#
#                          production_companies      production_countries  \
# 0                     Pixar Animation Studios  United States of America
# 1                            TriStar Pictures  United States of America
# 2                                Warner Bros.  United States of America
# 3      Twentieth Century Fox Film Corporation  United States of America
# 4                       Sandollar Productions  United States of America
# ...                                       ...                       ...
# 45449                    Walt Disney Pictures  United States of America
# 45454              Oops Doughnuts Productions  United States of America
# 45456                      Universal Pictures  United States of America
# 45458             Neptune Salad Entertainment  United States of America
# 45463                 American World Pictures  United States of America
#
#            revenue  runtime spoken_languages    status  \
# 0      373554033.0     81.0          English  Released
# 1      262797249.0    104.0          English  Released
# 2              0.0    101.0          English  Released
# 3       81452156.0    127.0          English  Released
# 4       76578911.0    106.0          English  Released
# ...            ...      ...              ...       ...
# 45449          0.0     67.0          English  Released
# 45454          0.0     79.0          English  Released
# 45456          0.0     65.0          English  Released
# 45458          0.0     30.0          English  Released
# 45463          0.0     90.0          English  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45449                 Celebrate Lumpy's First Halloween.
# 45454                          What happened last night?
# 45456                                Meet...The CREEPER!
# 45458  Do you know what happened 50 years before "The...
# 45463                             A deadly game of wits.
#
#                                   title  vote_average  vote_count  \
# 0                             Toy Story           7.7      5415.0
# 1                               Jumanji           6.9      2413.0
# 2                      Grumpier Old Men           6.5        92.0
# 3                     Waiting to Exhale           6.1        34.0
# 4           Father of the Bride Part II           5.7       173.0
# ...                                 ...           ...         ...
# 45449  Pooh's Heffalump Halloween Movie           5.4         7.0
# 45454                 The Morning After           4.0         2.0
# 45456                  House of Horrors           6.3         8.0
# 45458               The Burkittsville 7           7.0         1.0
# 45463                          Betrayal           3.8         6.0
#
#       release_date release_year     return
# 0       1995-10-30         1995  12.451801
# 1       1995-12-15         1995   4.043035
# 2       1995-12-22         1995   0.000000
# 3       1995-12-22         1995   5.090760
# 4       1995-02-10         1995   0.000000
# ...            ...          ...        ...
# 45449          NaN          NaN   0.000000
# 45454          NaN          NaN   0.000000
# 45456          NaN          NaN   0.000000
# 45458          NaN          NaN   0.000000
# 45463          NaN          NaN   0.000000
#
# [40240 rows x 19 columns]
